# %%
# %sql
-- REVERSIÓN LÓGICA DE TABLAS (Unity Catalog)
-- Ejecutar este script para limpiar el catálogo de metadatos

-- 1. Eliminar Capa GOLD
DROP TABLE IF EXISTS catalog_footballdata.golden.agg_possession_stats;
DROP TABLE IF EXISTS catalog_footballdata.golden.agg_defensive_blocks;
DROP TABLE IF EXISTS catalog_footballdata.golden.agg_player_evolution;

-- 2. Eliminar Capa SILVER
DROP TABLE IF EXISTS catalog_footballdata.silver.fact_match_events;
DROP TABLE IF EXISTS catalog_footballdata.silver.fact_physical_performance;

-- 3. Eliminar Capa BRONZE
DROP TABLE IF EXISTS catalog_footballdata.bronze.match_events;
DROP TABLE IF EXISTS catalog_footballdata.bronze.physical_performance;
DROP TABLE IF EXISTS catalog_footballdata.bronze.teams;
DROP TABLE IF EXISTS catalog_footballdata.bronze.competitions;

-- Eliminar Esquemas (si están vacíos)
-- DROP SCHEMA IF EXISTS catalog_footballdata.gold;
-- DROP SCHEMA IF EXISTS catalog_footballdata.silver;
-- DROP SCHEMA IF EXISTS catalog_footballdata.bronze;
